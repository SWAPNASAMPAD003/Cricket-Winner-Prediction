# %%
import numpy as np
import pandas as pd
# Out:
# Running cells with 'Python 3.11.4' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ashis/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
match=pd.read_csv("matches.csv")
delivery=pd.read_csv("deliveries.csv")

# %%
match
# Out:
#         id    Season           city        date                        team1
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad  \
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
delivery
# Out:
#         match_id  inning         batting_team                 bowling_team
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore  \
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
match.shape
# Out:
# (756, 18)

# %%
delivery.shape
# Out:
# (179078, 21)

# %% [markdown]
# We will keep those columns that are only rrquired for our prediction

# %%
delivery.groupby(["match_id","inning"]).sum()["total_runs"]
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
total_score_df=delivery.groupby(["match_id","inning"]).sum()["total_runs"].reset_index()
# total_score_df.rename(columns={'match_id':"id"},inplace=True)            # tried this to try the join 
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %% [markdown]
# Now we will only require the 1st innings score so that from that we will predict

# %%
total_score_df=total_score_df[total_score_df.inning==1]
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %% [markdown]
# NOW we will merge this total_df to match dataframe.In match dataframe there is no total runs in so we will add to it

# %%
# match.merge(total_score_df[['id','total_runs']],on='id')
match_df=match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#         id    Season           city        date                        team1
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad  \
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %% [markdown]
# Now we will keep those teams that are playing now

# %%
teams=['Sunrisers Hyderabad',
        'Mumbai Indians',
        'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
         'Kings XI Punjab',
       'Chennai Super Kings',
         'Rajasthan Royals',
       'Delhi Capitals']

# %%
match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1']=match_df['team1'].str.replace('Decan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team1'].str.replace('Decan Chargers','Sunrisers Hyderabad')

# %%
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]

# %%
match.shape
# Out:
# (756, 18)

# %%
match_df.shape
# Out:
# (657, 20)

# %% [markdown]
# We require those matches where dls is not applied

# %%
match_df['dl_applied'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 match_df['dl_applied'].value_counts()
#
# NameError: name 'match_df' is not defined

# %%
match_df=match_df[match_df['dl_applied']==0]

# %%
match_df['dl_applied'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 match_df['dl_applied'].value_counts()
#
# NameError: name 'match_df' is not defined

# %% [markdown]
# Now we will keep those column from match_df and merge in delivery datafame bcz that columns are not in delivery dataframe

# %%
match_df=match_df[['match_id','city','winner','total_runs']]

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1  \
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0  \
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs
# ...

# %%
delivery_df=match_df.merge(delivery,on='match_id')
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1  \
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 152402     11415  Hyderabad       Mumbai Indians           152       2
# 152403     11415  Hyderabad       Mumbai Indians           152       2
# 152404     11415  Hyderabad       Mumbai Indians           152       2
# 152405     11415  Hyderabad       Mumbai Indians           152       2
# 152406     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball
# ...

# %% [markdown]
# now we will find the 2nd inning run

# %%
delivery_df=delivery_df[delivery_df['inning']==2]
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2  \
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 152402     11415  Hyderabad       Mumbai Indians           152       2
# 152403     11415  Hyderabad       Mumbai Indians           152       2
# 152404     11415  Hyderabad       Mumbai Indians           152       2
# 152405     11415  Hyderabad       Mumbai Indians           152       2
# 152406     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball
# ...

# %%
delivery_df['total_runs_y'].isna().sum()
# Out:
# 0

# %%
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()
delivery_df['current_score']
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\3418631958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()
# 125         1
# 126         1
# 127         1
# 128         3
# 129         7
#          ...
# 152402    152
# 152403    154
# 152404    155
# 152405    157
# 152406    157
# Name: current_score, Length: 73694, dtype: int64

# %%
delivery_df.head(50)
# Out:
#      match_id       city               winner  total_runs_x  inning
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2  \
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
# 130         1  Hyderabad  Sunrisers Hyderabad           207       2
# 131         1  Hyderabad  Sunrisers Hyderabad           207       2
# 132         1  Hyderabad  Sunrisers Hyderabad           207       2
# 133         1  Hyderabad  Sunrisers Hyderabad           207       2
# 134         1  Hyderabad  Sunrisers Hyderabad           207       2
# 135         1  Hyderabad  Sunrisers Hyderabad           207       2
# 136         1  Hyderabad  Sunrisers Hyderabad           207       2
# 137         1  Hyderabad  Sunrisers Hyderabad           207       2
# ...

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']+1-delivery_df['current_score']  #+1 for target
delivery_df
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\2018683706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left']=delivery_df['total_runs_x']+1-delivery_df['current_score']  #+1 for target
#         match_id       city               winner  total_runs_x  inning
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2  \
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
delivery_df['balls_left']=120-((delivery_df['over']-1)*6+delivery_df['ball'])
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\2341256049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left']=120-((delivery_df['over']-1)*6+delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2  \
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 152402     11415  Hyderabad       Mumbai Indians           152       2
# 152403     11415  Hyderabad       Mumbai Indians           152       2
# 152404     11415  Hyderabad       Mumbai Indians           152       2
# 152405     11415  Hyderabad       Mumbai Indians           152       2
# 152406     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball
# ...

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna(0)
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x==0 else 1)
wickets=delivery_df.groupby('match_id')['player_dismissed'].cumsum().values
delivery_df['wickets_left']=10-wickets
delivery_df.head(5)
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\4055810731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna(0)
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\4055810731.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x==0 else 1)
# ...

# %% [markdown]
# Now current runrate and required run rate

# %%
#balls played=
delivery_df['crr']=(delivery_df["current_score"]*6/(120-delivery_df['balls_left']))
delivery_df['crr']
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\3963877424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr']=(delivery_df["current_score"]*6/(120-delivery_df['balls_left']))
# 125       6.000000
# 126       3.000000
# 127       2.000000
# 128       4.500000
# 129       8.400000
#             ...
# 152402    7.862069
# 152403    7.897436
# 152404    7.881356
# 152405    7.915966
# 152406    7.850000
# Name: crr, Length: 73694, dtype: float64

# %%
delivery_df['rrr']=delivery_df['runs_left']*6/delivery_df['balls_left']
delivery_df['rrr']
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\1097991026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr']=delivery_df['runs_left']*6/delivery_df['balls_left']
# 125       10.436975
# 126       10.525424
# 127       10.615385
# 128       10.603448
# 129       10.486957
#             ...
# 152402     1.500000
# 152403    -2.000000
# 152404    -6.000000
# 152405   -24.000000
# 152406         -inf
# Name: rrr, Length: 73694, dtype: float64

# %% [markdown]
# creating the winner team as 0 and 1

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)
# Out:
# C:\Users\Aditya Narayan Swain\AppData\Local\Temp\ipykernel_22344\2671046774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
# delivery_df[(delivery_df["result"]==1) and (delivery_df['balls_left']==0)]

# %%
delivery_df[(delivery_df["result"] == 1) & (delivery_df['balls_left'] == 0)]
# Out:
#         match_id            city                       winner  total_runs_x
# 4590          25            Pune       Rising Pune Supergiant           176  \
# 6343          37          Mumbai               Mumbai Indians           162
# 7732          46      Chandigarh                Gujarat Lions           189
# 15289         87           Delhi          Chennai Super Kings           187
# 20461        113          Jaipur             Rajasthan Royals           145
# 21149        117          Mumbai             Rajasthan Royals           163
# 25735        142  Port Elizabeth              Kings XI Punjab           153
# 29831        163    Johannesburg              Deccan Chargers           160
# 30584        166       Centurion        Kolkata Knight Riders           188
# 55356        303         Kolkata               Mumbai Indians           175
# 58634        320         Chennai          Chennai Super Kings           205
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'is_super_over', 'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs',
#        'penalty_runs', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'current_score',
#        'runs_left', 'balls_left', 'wickets_left', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr', 'rrr', 'result']]
final_df
# Out:
#                        batting_team         bowling_team       city
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad  \
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 152402          Chennai Super Kings       Mumbai Indians  Hyderabad
# 152403          Chennai Super Kings       Mumbai Indians  Hyderabad
# 152404          Chennai Super Kings       Mumbai Indians  Hyderabad
# 152405          Chennai Super Kings       Mumbai Indians  Hyderabad
# 152406          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr
# 125           207         119            10           207  6.000000  \
# ...

# %%
final_df=final_df.sample(final_df.shape[0])
final_df.sample()
# Out:
#                       batting_team     bowling_team        city  runs_left
# 38840  Royal Challengers Bangalore  Kings XI Punjab  Chandigarh         17  \
#
#        balls_left  wickets_left  total_runs_x       crr  rrr  result
# 38840          15             7           181  9.428571  6.8       1

# %% [markdown]
# BUILIDING THE MODEL

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets_left      0
# total_runs_x      0
# crr               0
# rrr               5
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
from sklearn.model_selection import train_test_split

# %%
X=final_df.drop(columns=['result'])
y=final_df['result']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                  batting_team                 bowling_team       city
# 1170          Kings XI Punjab  Royal Challengers Bangalore     Indore  \
# 94359        Rajasthan Royals  Royal Challengers Bangalore  Bangalore
# 93126     Chennai Super Kings              Kings XI Punjab    Cuttack
# 28527         Deccan Chargers             Delhi Daredevils     Durban
# 98961   Kolkata Knight Riders          Sunrisers Hyderabad    Kolkata
# ...                       ...                          ...        ...
# 44352   Kolkata Knight Riders               Mumbai Indians    Kolkata
# 1173          Kings XI Punjab  Royal Challengers Bangalore     Indore
# 123239          Gujarat Lions               Mumbai Indians     Kanpur
# 33963   Kolkata Knight Riders          Chennai Super Kings    Kolkata
# 3284            Gujarat Lions  Royal Challengers Bangalore     Rajkot
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr        rrr
# ...

# %%
X_test
# Out:
#                        batting_team           bowling_team       city
# 2638                Kings XI Punjab       Delhi Daredevils      Delhi  \
# 139465              Kings XI Punjab  Kolkata Knight Riders    Kolkata
# 13380         Kolkata Knight Riders       Rajasthan Royals     Jaipur
# 36869   Royal Challengers Bangalore       Delhi Daredevils  Bangalore
# 134986             Rajasthan Royals         Mumbai Indians     Mumbai
# ...                             ...                    ...        ...
# 42199              Rajasthan Royals         Mumbai Indians     Jaipur
# 126914          Chennai Super Kings        Kings XI Punjab     Mohali
# 79447              Delhi Daredevils  Kolkata Knight Riders     Raipur
# 72909                 Pune Warriors         Mumbai Indians     Mumbai
# 107343        Kolkata Knight Riders    Chennai Super Kings    Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr        rrr
# ...

# %% [markdown]
# AS there 3 columns are string columns so we have to apply one hot encoding

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder

# %%
trf=ColumnTransformer([
    ('trf',OneHotEncoder(drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
trf
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('trf', OneHotEncoder(drop='first'),
#                                  ['batting_team', 'bowling_team', 'city'])])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'
    ))
])

# %%
# pipe.fit(X_train,y_train)

# ValueError: Input X contains infinity or a value too large for dtype('float64'). as we have not changed in rrr there are some infinity value

# %%
X_train.describe()
# Out:
#           runs_left    balls_left  wickets_left  total_runs_x           crr
# count  58088.000000  58088.000000  58088.000000  58088.000000  58088.000000  \
# mean      93.712505     62.897724      7.543864    165.828347      7.457935
# std       50.038340     33.248571      2.124980     29.618591      2.274874
# min      -15.000000     -2.000000      0.000000     65.000000      0.000000
# 25%       54.000000     35.000000      6.000000    147.000000      6.272727
# 50%       93.000000     64.000000      8.000000    165.000000      7.500000
# 75%      131.000000     92.000000      9.000000    185.000000      8.709677
# max      264.000000    119.000000     10.000000    263.000000     42.000000
#
#                 rrr
# count  58088.000000
# mean      10.681960
# std       14.427212
# min     -516.000000
# 25%        7.254545
# 50%        9.000000
# 75%       11.090909
# max      792.000000

# %% [markdown]
# as where the balls left are 0 this is causing infinity
#
# so remove the rows where balls left=0
#
# see above after the droping of nan value of finaldf

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8089926323762308

# %% [markdown]
# If we use randomforest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipe2=Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
pipe2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
y_pred2=pipe2.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9994491496247332

# %% [markdown]
# AS we can see that the model is 99% accurate. BCZ the data is very straight forward for the model.if i use r=this model and pick a row data i will more accurately predict which team will win.But i require at every point of time the probability of winning of both the team so i will use logistic regression

# %% [markdown]
# random forest also has a probabiity function that also predict the probabilty but that is very high.

# %%
print(pipe2.predict_proba(X_test)[0])
print(pipe2.predict_proba(X_test)[15])
print(pipe2.predict_proba(X_test)[25])
print(pipe2.predict_proba(X_test)[35])
print(pipe2.predict_proba(X_test)[45])
# Out:
# [1. 0.]
# [0.01 0.99]
# [0.98 0.02]
# [0.04 0.96]
# [0. 1.]

# %% [markdown]
# But if we use logistic regressrion it will give more comaprable value

# %%
print(pipe.predict_proba(X_test)[0])
print(pipe.predict_proba(X_test)[15])
print(pipe.predict_proba(X_test)[25])
print(pipe.predict_proba(X_test)[35])
print(pipe.predict_proba(X_test)[45])
# Out:
# [0.97714797 0.02285203]
# [0.0836837 0.9163163]
# [0.67914586 0.32085414]
# [0.35820474 0.64179526]
# [0.16093483 0.83906517]

# %% [markdown]
# SO we will use logistic regression

# %% [markdown]
# now we will analyze a whole match (2nd inning) ball by ball

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2  \
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 152402     11415  Hyderabad       Mumbai Indians           152       2
# 152403     11415  Hyderabad       Mumbai Indians           152       2
# 152404     11415  Hyderabad       Mumbai Indians           152       2
# 152405     11415  Hyderabad       Mumbai Indians           152       2
# 152406     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball
# ...

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target=match_progression(delivery_df,74,pipe)
print("runs scored= ",temp_df['runs_after_over'].sum())
temp_df
# Out:
# Target- 178
# runs scored=  161
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 12572            1                3                0  57.1  42.9
# 12580            2                8                0  51.7  48.3
# 12586            3                1                0  58.7  41.3
# 12592            4                7                1  70.6  29.4
# 12598            5               12                0  60.3  39.7
# 12604            6               13                0  47.7  52.3
# 12610            7                9                0  41.6  58.4
# 12618            8               15                0  27.3  72.7
# 12624            9                7                0  25.1  74.9
# 12631           10               17                0  13.4  86.6
# 12637           11                9                1  18.8  81.2
# 12643           12                9                0  15.3  84.7
# 12649           13                8                0  13.1  86.9
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='green',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-156')

# %% [markdown]
# Now creating the app

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata',
#        'Delhi', 'Rajkot', 'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town',
#        'Port Elizabeth', 'Durban', 'Centurion', 'East London',
#        'Johannesburg', 'Kimberley', 'Bloemfontein', 'Ahmedabad', 'Nagpur',
#        'Dharamsala', 'Kochi', 'Visakhapatnam', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', nan, 'Cuttack', 'Kanpur', 'Mohali',
#        'Bengaluru'], dtype=object)

# %%
import pickle

# %%
pickle.dump(pipe,open('adi.pkl','wb'))
